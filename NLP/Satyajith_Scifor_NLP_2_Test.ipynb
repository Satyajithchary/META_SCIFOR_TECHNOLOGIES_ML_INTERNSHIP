# %% [markdown]
# # NLP Text Preprocessing Test
#
# **Total Marks: 50**
#
# ## Story
#
# In the rugged terrain of the Western Ghats, Shivaji Maharaj, the founder of the Maratha Empire, was preparing for another day of strategic planning and military campaigns. Known for his innovative tactics and leadership, Shivaji Maharaj was determined to strengthen his kingdom and protect his people from external threats.
#
# Shivaji Maharaj’s stronghold was the Raigad Fort, a formidable fortress perched high on a hilltop. The fort's strategic location allowed him to oversee the surrounding lands and defend against invaders. His trusted advisors and generals would gather in the fort's grand hall to discuss plans, share intelligence, and make critical decisions for the empire's expansion.
#
# The evenings in Shivaji Maharaj's court were vibrant with activity. He would host feasts and gatherings to bolster the morale of his soldiers and celebrate victories. During these events, Shivaji Maharaj would address his people, sharing his vision for a prosperous and united Maratha Empire. His leadership inspired loyalty and courage among his subjects.
#
# As night fell, Shivaji Maharaj would retire to his quarters, reflecting on the day's achievements and preparing for the challenges ahead. His dreams were filled with visions of a strong and resilient empire, where justice and valor would prevail.
#
# ## Questions
#
# 1. **Tokenization (3 marks)**
#    a. Tokenize the story into sentences.
#    b. Tokenize the story into words.
#
# 2. **Lowercasing (3 marks)**
#    Convert all words in the story to lowercase. Provide the transformed text.
#
# 3. **Stopword Removal (3 marks)**
#    a. Remove common stopwords (e.g., 'the', 'was', 'a') from the story.
#    b. List the removed stopwords.
#
# 4. **Punctuation Removal (3 marks)**
#    Remove all punctuation marks from the story. Provide the cleaned text.
#
# 5. **Stemming (3 marks)**
#    a. Apply stemming to the words in the story.
#    b. Provide a few examples of stemmed words.
#
# 6. **Lemmatization (3 marks)**
#    a. Apply lemmatization to the words in the story.
#    b. Provide a few examples of lemmatized words.
#
# 7. **Named Entity Recognition (NER) (3 marks)**
#    Identify and list all named entities (e.g., people, locations) in the story.
#
# 8. **Part-of-Speech Tagging (3 marks)**
#    Tag each word in the story with its corresponding part of speech. Provide the tagged text for a few sentences.
#
# 9. **Term Frequency (2 marks)**
#    Calculate the term frequency (TF) of the word "Shivaji" in the story.
#
# 10. **Frequency Distribution (3 marks)**
#     Plot the frequency distribution of the top 10 most common words in the story. Describe the results.
#
# 11. **Token Count (2 marks)**
#     Count the total number of tokens (words) in the story.
#
# 12. **Sentence Count (2 marks)**
#     Count the total number of sentences in the story.
#
# 13. **Stopword Frequency (2 marks)**
#     Calculate the frequency of stopwords in the story. Provide the top 3 most frequent stopwords.
#
# 14. **Longest Word (2 marks)**
#     Identify the longest word in the story and its length.
#
# 15. **Word Cloud (3 marks)**
#     Create a word cloud based on the story. Describe the most prominent words in the cloud.
#
# 16. **Noun Identification (2 marks)**
#     Identify and list all nouns in the story.
#
# 17. **Verb Identification (2 marks)**
#     Identify and list all verbs in the story.
#
# 18. **Word Context (2 marks)**
#     Find and list the sentences where the word "empire" appears.
#
# 19. **Named Entity Categorization (2 marks)**
#     Categorize the identified named entities into people, locations, and organizations.
#
# 20. **Word Frequency Comparison (2 marks)**
#     Compare the frequency of the words "kingdom" and "feast" in the story. Provide their counts and analyze the difference.
#
# ---
#
# ### Instructions
#
# - Use Python libraries like `nltk`, `spaCy`, `wordcloud`, etc., where appropriate.
# - Ensure to follow the specified format for each task.
# - Write clear and concise explanations for your results where required.
# - Submit your notebook as a PDF file.
#
# Good luck!

# %% [markdown]
# # **Q1 A**

# %%
import nltk
nltk.download('punkt')
from nltk.tokenize import sent_tokenize, word_tokenize

story = """In the rugged terrain of the Western Ghats, Shivaji Maharaj, the founder of the Maratha Empire, was preparing for another day of strategic planning and military campaigns. Known for his innovative tactics and leadership, Shivaji Maharaj was determined to strengthen his kingdom and protect his people from external threats.

Shivaji Maharaj’s stronghold was the Raigad Fort, a formidable fortress perched high on a hilltop. The fort's strategic location allowed him to oversee the surrounding lands and defend against invaders. His trusted advisors and generals would gather in the fort's grand hall to discuss plans, share intelligence, and make critical decisions for the empire's expansion.

The evenings in Shivaji Maharaj's court were vibrant with activity. He would host feasts and gatherings to bolster the morale of his soldiers and celebrate victories. During these events, Shivaji Maharaj would address his people, sharing his vision for a prosperous and united Maratha Empire. His leadership inspired loyalty and courage among his subjects.

As night fell, Shivaji Maharaj would retire to his quarters, reflecting on the day's achievements and preparing for the challenges ahead. His dreams were filled with visions of a strong and resilient empire, where justice and valor would prevail."""

sentences = sent_tokenize(story)
print("Sentence :", sentences)
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# Sentence : ['In the rugged terrain of the Western Ghats, Shivaji Maharaj, the founder of the Maratha Empire, was preparing for another day of strategic planning and military campaigns.', 'Known for his innovative tactics and leadership, Shivaji Maharaj was determined to strengthen his kingdom and protect his people from external threats.', 'Shivaji Maharaj’s stronghold was the Raigad Fort, a formidable fortress perched high on a hilltop.', "The fort's strategic location allowed him to oversee the surrounding lands and defend against invaders.", "His trusted advisors and generals would gather in the fort's grand hall to discuss plans, share intelligence, and make critical decisions for the empire's expansion.", "The evenings in Shivaji Maharaj's court were vibrant with activity.", 'He would host feasts and gatherings to bolster the morale of his soldiers and celebrate victories.', 'During these events, Shivaji Maharaj would address his people, sharing his vision for a prosperous and united Maratha Empire.', 'His leadership inspired loyalty and courage among his subjects.', "As night fell, Shivaji Maharaj would retire to his quarters, reflecting on the day's achievements and preparing for the challenges ahead.", 'His dreams were filled with visions of a strong and resilient empire, where justice and valor would prevail.']

# %% [markdown]
# # **Q1 B**

# %%
words = word_tokenize(story)
print("Words:", words)
# Out:
# Words: ['In', 'the', 'rugged', 'terrain', 'of', 'the', 'Western', 'Ghats', ',', 'Shivaji', 'Maharaj', ',', 'the', 'founder', 'of', 'the', 'Maratha', 'Empire', ',', 'was', 'preparing', 'for', 'another', 'day', 'of', 'strategic', 'planning', 'and', 'military', 'campaigns', '.', 'Known', 'for', 'his', 'innovative', 'tactics', 'and', 'leadership', ',', 'Shivaji', 'Maharaj', 'was', 'determined', 'to', 'strengthen', 'his', 'kingdom', 'and', 'protect', 'his', 'people', 'from', 'external', 'threats', '.', 'Shivaji', 'Maharaj', '’', 's', 'stronghold', 'was', 'the', 'Raigad', 'Fort', ',', 'a', 'formidable', 'fortress', 'perched', 'high', 'on', 'a', 'hilltop', '.', 'The', 'fort', "'s", 'strategic', 'location', 'allowed', 'him', 'to', 'oversee', 'the', 'surrounding', 'lands', 'and', 'defend', 'against', 'invaders', '.', 'His', 'trusted', 'advisors', 'and', 'generals', 'would', 'gather', 'in', 'the', 'fort', "'s", 'grand', 'hall', 'to', 'discuss', 'plans', ',', 'share', 'intelligence', ',', 'and', 'make', 'critical', 'decisions', 'for', 'the', 'empire', "'s", 'expansion', '.', 'The', 'evenings', 'in', 'Shivaji', 'Maharaj', "'s", 'court', 'were', 'vibrant', 'with', 'activity', '.', 'He', 'would', 'host', 'feasts', 'and', 'gatherings', 'to', 'bolster', 'the', 'morale', 'of', 'his', 'soldiers', 'and', 'celebrate', 'victories', '.', 'During', 'these', 'events', ',', 'Shivaji', 'Maharaj', 'would', 'address', 'his', 'people', ',', 'sharing', 'his', 'vision', 'for', 'a', 'prosperous', 'and', 'united', 'Maratha', 'Empire', '.', 'His', 'leadership', 'inspired', 'loyalty', 'and', 'courage', 'among', 'his', 'subjects', '.', 'As', 'night', 'fell', ',', 'Shivaji', 'Maharaj', 'would', 'retire', 'to', 'his', 'quarters', ',', 'reflecting', 'on', 'the', 'day', "'s", 'achievements', 'and', 'preparing', 'for', 'the', 'challenges', 'ahead', '.', 'His', 'dreams', 'were', 'filled', 'with', 'visions', 'of', 'a', 'strong', 'and', 'resilient', 'empire', ',', 'where', 'justice', 'and', 'valor', 'would', 'prevail', '.']

# %% [markdown]
# # **Q2**

# %%
lowercased_story = story.lower()
print("Story in Lower Case:", lowercased_story)
# Out:
# Story in Lower Case: in the rugged terrain of the western ghats, shivaji maharaj, the founder of the maratha empire, was preparing for another day of strategic planning and military campaigns. known for his innovative tactics and leadership, shivaji maharaj was determined to strengthen his kingdom and protect his people from external threats.
#
# shivaji maharaj’s stronghold was the raigad fort, a formidable fortress perched high on a hilltop. the fort's strategic location allowed him to oversee the surrounding lands and defend against invaders. his trusted advisors and generals would gather in the fort's grand hall to discuss plans, share intelligence, and make critical decisions for the empire's expansion.
#
# the evenings in shivaji maharaj's court were vibrant with activity. he would host feasts and gatherings to bolster the morale of his soldiers and celebrate victories. during these events, shivaji maharaj would address his people, sharing his vision for a prosperous and united maratha empire. his leadership inspired loyalty and courage among his subjects.
#
# as night fell, shivaji maharaj would retire to his quarters, reflecting on the day's achievements and preparing for the challenges ahead. his dreams were filled with visions of a strong and resilient empire, where justice and valor would prevail.

# %% [markdown]
# # **Q3 A**

# %%
from nltk.corpus import stopwords
nltk.download('stopwords')

stop_words = set(stopwords.words('english'))
words_filtered = [word for word in words if word.lower() not in stop_words]
print("Filtered Words:", words_filtered)
# Out:
# Filtered Words: ['rugged', 'terrain', 'Western', 'Ghats', ',', 'Shivaji', 'Maharaj', ',', 'founder', 'Maratha', 'Empire', ',', 'preparing', 'another', 'day', 'strategic', 'planning', 'military', 'campaigns', '.', 'Known', 'innovative', 'tactics', 'leadership', ',', 'Shivaji', 'Maharaj', 'determined', 'strengthen', 'kingdom', 'protect', 'people', 'external', 'threats', '.', 'Shivaji', 'Maharaj', '’', 'stronghold', 'Raigad', 'Fort', ',', 'formidable', 'fortress', 'perched', 'high', 'hilltop', '.', 'fort', "'s", 'strategic', 'location', 'allowed', 'oversee', 'surrounding', 'lands', 'defend', 'invaders', '.', 'trusted', 'advisors', 'generals', 'would', 'gather', 'fort', "'s", 'grand', 'hall', 'discuss', 'plans', ',', 'share', 'intelligence', ',', 'make', 'critical', 'decisions', 'empire', "'s", 'expansion', '.', 'evenings', 'Shivaji', 'Maharaj', "'s", 'court', 'vibrant', 'activity', '.', 'would', 'host', 'feasts', 'gatherings', 'bolster', 'morale', 'soldiers', 'celebrate', 'victories', '.', 'events', ',', 'Shivaji', 'Maharaj', 'would', 'address', 'people', ',', 'sharing', 'vision', 'prosperous', 'united', 'Maratha', 'Empire', '.', 'leadership', 'inspired', 'loyalty', 'courage', 'among', 'subjects', '.', 'night', 'fell', ',', 'Shivaji', 'Maharaj', 'would', 'retire', 'quarters', ',', 'reflecting', 'day', "'s", 'achievements', 'preparing', 'challenges', 'ahead', '.', 'dreams', 'filled', 'visions', 'strong', 'resilient', 'empire', ',', 'justice', 'valor', 'would', 'prevail', '.']
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.

# %% [markdown]
# # **Q3 B**

# %%
removed_stopwords = [word for word in words if word.lower() in stop_words]
print("Removed Stopwords:", removed_stopwords)
# Out:
# Removed Stopwords: ['In', 'the', 'of', 'the', 'the', 'of', 'the', 'was', 'for', 'of', 'and', 'for', 'his', 'and', 'was', 'to', 'his', 'and', 'his', 'from', 's', 'was', 'the', 'a', 'on', 'a', 'The', 'him', 'to', 'the', 'and', 'against', 'His', 'and', 'in', 'the', 'to', 'and', 'for', 'the', 'The', 'in', 'were', 'with', 'He', 'and', 'to', 'the', 'of', 'his', 'and', 'During', 'these', 'his', 'his', 'for', 'a', 'and', 'His', 'and', 'his', 'As', 'to', 'his', 'on', 'the', 'and', 'for', 'the', 'His', 'were', 'with', 'of', 'a', 'and', 'where', 'and']

# %% [markdown]
# # **Q4**

# %%
import string

story_no_punctuation = story.translate(str.maketrans('', '', string.punctuation))
print("Story without Punctuation:", story_no_punctuation)
# Out:
# Story without Punctuation: In the rugged terrain of the Western Ghats Shivaji Maharaj the founder of the Maratha Empire was preparing for another day of strategic planning and military campaigns Known for his innovative tactics and leadership Shivaji Maharaj was determined to strengthen his kingdom and protect his people from external threats
#
# Shivaji Maharaj’s stronghold was the Raigad Fort a formidable fortress perched high on a hilltop The forts strategic location allowed him to oversee the surrounding lands and defend against invaders His trusted advisors and generals would gather in the forts grand hall to discuss plans share intelligence and make critical decisions for the empires expansion
#
# The evenings in Shivaji Maharajs court were vibrant with activity He would host feasts and gatherings to bolster the morale of his soldiers and celebrate victories During these events Shivaji Maharaj would address his people sharing his vision for a prosperous and united Maratha Empire His leadership inspired loyalty and courage among his subjects
#
# As night fell Shivaji Maharaj would retire to his quarters reflecting on the days achievements and preparing for the challenges ahead His dreams were filled with visions of a strong and resilient empire where justice and valor would prevail

# %% [markdown]
# # **Q5 A**

# %%
from nltk.stem import PorterStemmer

ps = PorterStemmer()
stemmed_words = [ps.stem(word) for word in words_filtered]
print("Stemmed Words:", stemmed_words)
# Out:
# Stemmed Words: ['rug', 'terrain', 'western', 'ghat', ',', 'shivaji', 'maharaj', ',', 'founder', 'maratha', 'empir', ',', 'prepar', 'anoth', 'day', 'strateg', 'plan', 'militari', 'campaign', '.', 'known', 'innov', 'tactic', 'leadership', ',', 'shivaji', 'maharaj', 'determin', 'strengthen', 'kingdom', 'protect', 'peopl', 'extern', 'threat', '.', 'shivaji', 'maharaj', '’', 'stronghold', 'raigad', 'fort', ',', 'formid', 'fortress', 'perch', 'high', 'hilltop', '.', 'fort', "'s", 'strateg', 'locat', 'allow', 'overse', 'surround', 'land', 'defend', 'invad', '.', 'trust', 'advisor', 'gener', 'would', 'gather', 'fort', "'s", 'grand', 'hall', 'discuss', 'plan', ',', 'share', 'intellig', ',', 'make', 'critic', 'decis', 'empir', "'s", 'expans', '.', 'even', 'shivaji', 'maharaj', "'s", 'court', 'vibrant', 'activ', '.', 'would', 'host', 'feast', 'gather', 'bolster', 'moral', 'soldier', 'celebr', 'victori', '.', 'event', ',', 'shivaji', 'maharaj', 'would', 'address', 'peopl', ',', 'share', 'vision', 'prosper', 'unit', 'maratha', 'empir', '.', 'leadership', 'inspir', 'loyalti', 'courag', 'among', 'subject', '.', 'night', 'fell', ',', 'shivaji', 'maharaj', 'would', 'retir', 'quarter', ',', 'reflect', 'day', "'s", 'achiev', 'prepar', 'challeng', 'ahead', '.', 'dream', 'fill', 'vision', 'strong', 'resili', 'empir', ',', 'justic', 'valor', 'would', 'prevail', '.']

# %% [markdown]
# # **Q5 B**

# %%
examples = {word: ps.stem(word) for word in words_filtered[:10]}
print("Examples of Stemmed Words:", examples)
# Out:
# Examples of Stemmed Words: {'rugged': 'rug', 'terrain': 'terrain', 'Western': 'western', 'Ghats': 'ghat', ',': ',', 'Shivaji': 'shivaji', 'Maharaj': 'maharaj', 'founder': 'founder', 'Maratha': 'maratha'}

# %% [markdown]
# # **Q6 A**

# %%
import spacy

nlp = spacy.load("en_core_web_sm")
doc = nlp(story)
lemmatized_words = [token.lemma_ for token in doc if token.text.lower() not in stop_words and token.is_alpha]
print("Lemmatized Words:", lemmatized_words)
# Out:
# Lemmatized Words: ['rugged', 'terrain', 'Western', 'Ghats', 'Shivaji', 'Maharaj', 'founder', 'Maratha', 'Empire', 'prepare', 'another', 'day', 'strategic', 'planning', 'military', 'campaign', 'know', 'innovative', 'tactic', 'leadership', 'Shivaji', 'Maharaj', 'determined', 'strengthen', 'kingdom', 'protect', 'people', 'external', 'threat', 'Shivaji', 'Maharaj', 'stronghold', 'Raigad', 'Fort', 'formidable', 'fortress', 'perch', 'high', 'hilltop', 'fort', 'strategic', 'location', 'allow', 'oversee', 'surround', 'land', 'defend', 'invader', 'trust', 'advisor', 'general', 'would', 'gather', 'fort', 'grand', 'hall', 'discuss', 'plan', 'share', 'intelligence', 'make', 'critical', 'decision', 'empire', 'expansion', 'evening', 'Shivaji', 'Maharaj', 'court', 'vibrant', 'activity', 'would', 'host', 'feast', 'gathering', 'bolster', 'morale', 'soldier', 'celebrate', 'victory', 'event', 'Shivaji', 'Maharaj', 'would', 'address', 'people', 'share', 'vision', 'prosperous', 'united', 'Maratha', 'Empire', 'leadership', 'inspire', 'loyalty', 'courage', 'among', 'subject', 'night', 'fall', 'Shivaji', 'Maharaj', 'would', 'retire', 'quarter', 'reflect', 'day', 'achievement', 'prepare', 'challenge', 'ahead', 'dream', 'fill', 'vision', 'strong', 'resilient', 'empire', 'justice', 'valor', 'would', 'prevail']

# %% [markdown]
# # **Q6 B**

# %%
examples_lemmatized = {token.text: token.lemma_ for token in doc[:20]}
print( examples_lemmatized)
# Out:
# {'In': 'in', 'the': 'the', 'rugged': 'rugged', 'terrain': 'terrain', 'of': 'of', 'Western': 'Western', 'Ghats': 'Ghats', ',': ',', 'Shivaji': 'Shivaji', 'Maharaj': 'Maharaj', 'founder': 'founder', 'Maratha': 'Maratha', 'Empire': 'Empire', 'was': 'be'}

# %% [markdown]
# # **Q7**

# %%
entities = [(entity.text, entity.label_) for entity in doc.ents]
print("Named Entities:", entities)
# Out:
# Named Entities: [('Shivaji Maharaj', 'PERSON'), ('the Maratha Empire', 'GPE'), ('another day', 'DATE'), ('Shivaji Maharaj', 'PERSON'), ('Shivaji Maharaj’s', 'PERSON'), ('the Raigad Fort', 'GPE'), ("Shivaji Maharaj's", 'PERSON'), ('Shivaji Maharaj', 'PERSON'), ('Maratha Empire', 'PERSON'), ('night', 'TIME'), ('Shivaji Maharaj', 'PERSON'), ('day', 'DATE')]

# %% [markdown]
# # **Q8**

# %%
pos_tags = [(token.text, token.pos_) for token in doc]
print("Part-of-Speech Tags for a few sentences:", pos_tags[:100])
# Out:
# Part-of-Speech Tags for a few sentences: [('In', 'ADP'), ('the', 'DET'), ('rugged', 'ADJ'), ('terrain', 'NOUN'), ('of', 'ADP'), ('the', 'DET'), ('Western', 'PROPN'), ('Ghats', 'PROPN'), (',', 'PUNCT'), ('Shivaji', 'PROPN'), ('Maharaj', 'PROPN'), (',', 'PUNCT'), ('the', 'DET'), ('founder', 'NOUN'), ('of', 'ADP'), ('the', 'DET'), ('Maratha', 'PROPN'), ('Empire', 'PROPN'), (',', 'PUNCT'), ('was', 'AUX'), ('preparing', 'VERB'), ('for', 'ADP'), ('another', 'DET'), ('day', 'NOUN'), ('of', 'ADP'), ('strategic', 'ADJ'), ('planning', 'NOUN'), ('and', 'CCONJ'), ('military', 'ADJ'), ('campaigns', 'NOUN'), ('.', 'PUNCT'), ('Known', 'VERB'), ('for', 'ADP'), ('his', 'PRON'), ('innovative', 'ADJ'), ('tactics', 'NOUN'), ('and', 'CCONJ'), ('leadership', 'NOUN'), (',', 'PUNCT'), ('Shivaji', 'PROPN'), ('Maharaj', 'PROPN'), ('was', 'AUX'), ('determined', 'ADJ'), ('to', 'PART'), ('strengthen', 'VERB'), ('his', 'PRON'), ('kingdom', 'NOUN'), ('and', 'CCONJ'), ('protect', 'VERB'), ('his', 'PRON'), ('people', 'NOUN'), ('from', 'ADP'), ('external', 'ADJ'), ('threats', 'NOUN'), ('.', 'PUNCT'), ('\n\n', 'SPACE'), ('Shivaji', 'PROPN'), ('Maharaj', 'PROPN'), ('’s', 'PART'), ('stronghold', 'NOUN'), ('was', 'AUX'), ('the', 'DET'), ('Raigad', 'PROPN'), ('Fort', 'PROPN'), (',', 'PUNCT'), ('a', 'DET'), ('formidable', 'ADJ'), ('fortress', 'NOUN'), ('perched', 'VERB'), ('high', 'ADV'), ('on', 'ADP'), ('a', 'DET'), ('hilltop', 'NOUN'), ('.', 'PUNCT'), ('The', 'DET'), ('fort', 'NOUN'), ("'s", 'PART'), ('strategic', 'ADJ'), ('location', 'NOUN'), ('allowed', 'VERB'), ('him', 'PRON'), ('to', 'PART'), ('oversee', 'VERB'), ('the', 'DET'), ('surrounding', 'VERB'), ('lands', 'NOUN'), ('and', 'CCONJ'), ('defend', 'VERB'), ('against', 'ADP'), ('invaders', 'NOUN'), ('.', 'PUNCT'), ('His', 'PRON'), ('trusted', 'VERB'), ('advisors', 'NOUN'), ('and', 'CCONJ'), ('generals', 'NOUN'), ('would', 'AUX'), ('gather', 'VERB'), ('in', 'ADP'), ('the', 'DET')]

# %% [markdown]
# # **Q9**

# %%
tf_shivaji = words_filtered.count("Shivaji") / len(words_filtered)
print("Term Frequency of 'Shivaji':", tf_shivaji)
# Out:
# Term Frequency of 'Shivaji': 0.04

# %% [markdown]
# # **Q10**

# %%
from collections import Counter
import matplotlib.pyplot as plt

word_freq = Counter(words_filtered)
most_common_words = word_freq.most_common(15)
words, freqs = zip(*most_common_words)

plt.bar(words, freqs)
plt.title("Top 15 Most Common Words")
plt.xlabel("Words")
plt.ylabel("Frequency")
plt.show()

# %% [markdown]
# # **Q11**

# %%
total_tokens = len(words)
print("Total Number of Tokens:", total_tokens)
# Out:
# Total Number of Tokens: 15

# %% [markdown]
# # **Q12**

# %%
total_sentences = len(sentences)
print("Total Number of Sentences:", total_sentences)
# Out:
# Total Number of Sentences: 11

# %% [markdown]
# # **Q13**

# %%
stopword_freq = Counter(removed_stopwords)
most_common_stopwords = stopword_freq.most_common(3)
print("Top 3 Most Frequent Stopwords:", most_common_stopwords)
# Out:
# Top 3 Most Frequent Stopwords: [('and', 13), ('the', 11), ('his', 8)]

# %% [markdown]
# # **Q14**

# %%
longest_word = max(words_filtered, key=len)
print("Longest Word:", longest_word, "Length:", len(longest_word))
# Out:
# Longest Word: intelligence Length: 12

# %% [markdown]
# # **Q15**

# %%
from wordcloud import WordCloud
import matplotlib.pyplot as plt

wordcloud = WordCloud(width=800, height=400).generate(story_no_punctuation.lower())

plt.figure(figsize=(10, 5))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.show()

# %% [markdown]
# # **Q16**

# %%
nouns = [token.text for token in doc if token.pos_ == 'NOUN']
print("Nouns:", nouns)
# Out:
# Nouns: ['terrain', 'founder', 'day', 'planning', 'campaigns', 'tactics', 'leadership', 'kingdom', 'people', 'threats', 'stronghold', 'fortress', 'hilltop', 'fort', 'location', 'lands', 'invaders', 'advisors', 'generals', 'fort', 'hall', 'plans', 'share', 'intelligence', 'decisions', 'empire', 'expansion', 'evenings', 'court', 'activity', 'feasts', 'gatherings', 'morale', 'soldiers', 'victories', 'events', 'people', 'vision', 'leadership', 'loyalty', 'courage', 'subjects', 'night', 'quarters', 'day', 'achievements', 'challenges', 'dreams', 'visions', 'empire', 'justice']

# %% [markdown]
# # **Q17**

# %%
verbs = [token.text for token in doc if token.pos_ == 'VERB']
print("Verbs:", verbs)
# Out:
# Verbs: ['preparing', 'Known', 'strengthen', 'protect', 'perched', 'allowed', 'oversee', 'surrounding', 'defend', 'trusted', 'gather', 'discuss', 'make', 'host', 'bolster', 'celebrate', 'address', 'sharing', 'inspired', 'fell', 'retire', 'reflecting', 'preparing', 'filled', 'prevail']

# %% [markdown]
# # **Q18**

# %%
sentences_with_empire = [sentence for sentence in sentences if 'empire' in sentence.lower()]
print("Sentences with 'Empire':", sentences_with_empire)
# Out:
# Sentences with 'Empire': ['In the rugged terrain of the Western Ghats, Shivaji Maharaj, the founder of the Maratha Empire, was preparing for another day of strategic planning and military campaigns.', "His trusted advisors and generals would gather in the fort's grand hall to discuss plans, share intelligence, and make critical decisions for the empire's expansion.", 'During these events, Shivaji Maharaj would address his people, sharing his vision for a prosperous and united Maratha Empire.', 'His dreams were filled with visions of a strong and resilient empire, where justice and valor would prevail.']

# %% [markdown]
# # **Q19**

# %%
people = [entity.text for entity in doc.ents if entity.label_ == 'PERSON']
locations = [entity.text for entity in doc.ents if entity.label_ == 'GPE']
organizations = [entity.text for entity in doc.ents if entity.label_ == 'ORG']

print("People:", people)
print("Locations:", locations)
print("Organizations:", organizations)
# Out:
# People: ['Shivaji Maharaj', 'Shivaji Maharaj', 'Shivaji Maharaj’s', "Shivaji Maharaj's", 'Shivaji Maharaj', 'Maratha Empire', 'Shivaji Maharaj']
# Locations: ['the Maratha Empire', 'the Raigad Fort']
# Organizations: []

# %% [markdown]
# # **Q20**

# %%
freq_kingdom = words_filtered.count('kingdom')
freq_feast = words_filtered.count('feast')

print("Frequency of 'Kingdom':", freq_kingdom)
print("Frequency of 'Feast':", freq_feast)
# Out:
# Frequency of 'Kingdom': 1
# Frequency of 'Feast': 0
